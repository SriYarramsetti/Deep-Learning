# %% [markdown]
# ## Problem3(ConcentricCircle2)

# %%
data3=pd.read_csv(r"C:\Users\harsh\Downloads\data (1)\demo_data\3.concertriccir2.csv",header=None)

# %%
data3.head()
# Out:
#           0         1    2
# 0  0.700335 -0.247068  0.0
# 1 -3.950019  2.740080  1.0
# 2  0.150222 -2.157638  1.0
# 3 -1.672050 -0.941519  1.0
# 4  2.560483 -1.846577  1.0

# %%
data3[2].value_counts()
# Out:
# 0.0    250
# 1.0    250
# Name: 2, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data3[[0,1]],data3[2],test_size=0.15)

# %%
from sklearn.preprocessing import StandardScaler
scaler3=StandardScaler()

# %%
data_rescaled=scaler3.fit_transform(X_train)

# %%
import tensorflow
import tensorflow.keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
model3=Sequential()

# %%
model3.add(Dense(7,activation="sigmoid",input_dim=2))
model3.add(Dense(5,activation="sigmoid"))
model3.add(Dense(4,activation="sigmoid"))
model3.add(Dense(3,activation="sigmoid"))
model3.add(Dense(1,activation="sigmoid"))

# %%
model3.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_60 (Dense)            (None, 7)                 21
#
#  dense_61 (Dense)            (None, 5)                 40
#
#  dense_62 (Dense)            (None, 4)                 24
#
#  dense_63 (Dense)            (None, 3)                 15
#
#  dense_64 (Dense)            (None, 1)                 4
#
# ...
# Total params: 104
# Trainable params: 104
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
model3.fit(X_train,y_train,batch_size=10,epochs=600,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/600
# 43/43 [==============================] - 1s 969us/step - loss: 0.6934
# Epoch 2/600
# 43/43 [==============================] - 0s 991us/step - loss: 0.6932
# Epoch 3/600
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6932
# Epoch 4/600
# 43/43 [==============================] - 0s 774us/step - loss: 0.6931
# Epoch 5/600
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6931
# Epoch 6/600
# 43/43 [==============================] - 0s 962us/step - loss: 0.6931
# Epoch 7/600
# 43/43 [==============================] - 0s 769us/step - loss: 0.6933
# Epoch 8/600
# 43/43 [==============================] - 0s 971us/step - loss: 0.6931
# Epoch 9/600
# 43/43 [==============================] - 0s 770us/step - loss: 0.6930
# Epoch 10/600
# 43/43 [==============================] - 0s 785us/step - loss: 0.6930
# Epoch 11/600
# 43/43 [==============================] - 0s 968us/step - loss: 0.6930
# Epoch 12/600
# ...

# %%
pred3=model3.predict(X_train)
# Out:
# 14/14 [==============================] - 0s 615us/step

# %%
pred3=np.ravel(np.where(pred3<0.5,0,1))
pred3=pd.Series(pred3)
pred3.index=y_train.index
pred3
# Out:
# 254    1
# 312    0
# 161    0
# 478    1
# 235    1
#       ..
# 221    1
# 302    1
# 192    0
# 287    1
# 471    1
# Length: 425, dtype: int32

# %%
sns.scatterplot(x=X_train[0],y=X_train[1],hue=y_train)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
sns.scatterplot(x=X_train[0],y=X_train[1],hue=pred_)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
metrics.accuracy_score(y_train,pred_)
# Out:
# 0.7952941176470588

# %% [markdown]
# #### Using batch normalization and weights initialization

# %%
import tensorflow
import tensorflow.keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
model3_=Sequential()

# %%
model3_.add(Dense(7,activation="relu",input_dim=2, kernel_initializer='he_uniform'))
model3_.add(Dense(3,activation="relu", kernel_initializer='he_uniform'))
model3_.add(BatchNormalization())
model3_.add(Dense(1,activation="sigmoid"))

# %%
model3_.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
model3_.fit(X_train,y_train,batch_size=10,epochs=200,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/200
# 34/34 [==============================] - 1s 4ms/step - loss: 0.8143 - accuracy: 0.4529 - val_loss: 0.7679 - val_accuracy: 0.4588
# Epoch 2/200
# 34/34 [==============================] - 0s 2ms/step - loss: 0.8008 - accuracy: 0.4559 - val_loss: 0.7674 - val_accuracy: 0.3647
# Epoch 3/200
# 34/34 [==============================] - 0s 2ms/step - loss: 0.7618 - accuracy: 0.4706 - val_loss: 0.7719 - val_accuracy: 0.3765
# Epoch 4/200
# 34/34 [==============================] - 0s 2ms/step - loss: 0.7679 - accuracy: 0.5000 - val_loss: 0.7687 - val_accuracy: 0.4706
# Epoch 5/200
# 34/34 [==============================] - 0s 2ms/step - loss: 0.7202 - accuracy: 0.5235 - val_loss: 0.7654 - val_accuracy: 0.4588
# Epoch 6/200
# 34/34 [==============================] - 0s 2ms/step - loss: 0.7417 - accuracy: 0.4618 - val_loss: 0.7615 - val_accuracy: 0.4706
# Epoch 7/200
# ...

# %%
pred3=model3_.predict(X_train)
# Out:
# 14/14 [==============================] - 0s 674us/step

# %%
y_train
# Out:
# 193    0.0
# 165    0.0
# 277    1.0
# 174    0.0
# 72     1.0
#       ...
# 200    0.0
# 284    1.0
# 148    1.0
# 171    1.0
# 180    0.0
# Name: 2, Length: 425, dtype: float64

# %%
pred3=np.ravel(np.where(pred3<0.5,0,1))
pred3=pd.Series(pred3)
pred3.index=y_train.index
pred3
# Out:
# 193    0
# 165    0
# 277    1
# 174    0
# 72     1
#       ..
# 200    1
# 284    1
# 148    1
# 171    1
# 180    0
# Length: 425, dtype: int32

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train[[0,1]].values,y_train.values.astype(int),clf=model3_)
# Out:
# 3888/3888 [==============================] - 2s 508us/step
# <AxesSubplot:>

# %%
metrics.accuracy_score(y_train,pred3)
# Out:
# 0.8682352941176471
